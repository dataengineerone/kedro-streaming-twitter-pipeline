# %%
import tweepy

# %%
consumer_key = '245Q3RR9DuINuZLc9uaXjw'
consumer_secret = 'gm6aOtfwDFHmxRE0FXyKd4U7LePcgIh2laOO2JV6DEM'

# %%
access_token = '152979775-09VjSKFFrri66I3ravLOHvVuiM1G3o7huIgFu6fV'
access_token_secret = 'pjKie1qcejbbeyoDGebBF9dPr48DrM5h0abHRIquJTAM6'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
api.home_timeline()
# Out:
# [Status(_api=<tweepy.api.API object at 0x12107ee10>, _json={'created_at': 'Fri May 29 20:08:33 +0000 2020', 'id': 1266461445610442752, 'id_str': '1266461445610442752', 'text': 'RT @josephfcox: New: Customs and Border Protection is flying a Predator drone over Minneapolis. Verified with multiple pieces of info that…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'josephfcox', 'name': 'Joseph Cox', 'id': 274991683, 'id_str': '274991683', 'indices': [3, 14]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 40283581, 'id_str': '40283581', 'name': '2600 Magazine', 'screen_name': '2600', 'location': 'We Are Everywhere', 'description': 'The Hacker Quarterly', 'url': 'http://t.co/YQS2NQlklJ', 'entities': {'url': {'ur
# ...

# %%
_5[0].created_at
# Out:
# datetime.datetime(2020, 5, 29, 20, 8, 33)

# %%
context.config_loader.get("credentials*")
# Out:
# {}

# %%
import datetime
current_dt = datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%S:%f')

# %%
import os

# %%
class TweetToYamlListener(tweepy.StreamListener):
    def __init__(self, path, *args, **kwargs):
        self._path = os.path.expanduser(path)
        super().__init__(*args, **kwargs)

    def on_status(self, status):
        import yaml
        import datetime
        dstr = '%Y-%m-%dT%H:%M:%S:%f'
        current_dt = datetime.datetime.now().strftime(dstr)
        with open(os.path.join(self._path, f'{current_dt}.yml'), 'w+', encoding='utf8') as f:
            yaml.dump(status._json, f)

# %%
myStreamListener = MyStreamListener('~/code/semi-realtime/data/01_raw/test_data')
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# %%
myStream.filter(track=['python'])

# %%
# !charm ..
